# %%
import ollama

# %%
ollama.list()
# Out:
# {'models': [{'name': 'llama:latest',
#    'model': 'llama:latest',
#    'modified_at': '2024-04-01T01:53:35.249741068+08:00',
#    'size': 3826794329,
#    'digest': '133f166d92084621a120c3f0b1cca94fbc0fe517b49dd41d89610fab6ce0e3f9',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '7B',
#     'quantization_level': 'Q4_0'}},
#   {'name': 'llama2:latest',
#    'model': 'llama2:latest',
#    'modified_at': '2024-04-01T02:17:00.512766524+08:00',
#    'size': 3826793677,
#    'digest': '78e26419b4469263f75331927a00a0284ef6544c1975b826b15abdaef17bb962',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '7B',
#     'quantization_level': 'Q4_0'}},
#   {'name': 'phi:latest',
#    'model': 'phi:latest',
#    'modified_at': '2024-04-01T02:16:42.842314617+08:00',
#    'size': 1602463378,
# ...

# %%
import ollama
response = ollama.chat(model='llama2:latest', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },])
print(response)
# Out:
# {'model': 'llama2:latest', 'created_at': '2024-04-02T07:31:17.080399Z', 'message': {'role': 'assistant', 'content': "\nThe sky appears blue because of a phenomenon called Rayleigh scattering. When sunlight enters Earth's atmosphere, it encounters tiny molecules of gases such as nitrogen and oxygen. These molecules scatter the light in all directions, but they scatter shorter (blue) wavelengths more than longer (red) wavelengths. This is known as Rayleigh scattering.\n\nAs a result of this scattering, the blue light is distributed throughout the atmosphere, giving the sky its blue appearance. The other colors in the spectrum, such as red and violet, are also present in the atmosphere but are not scattered as much as blue light, so they appear less intense.\n\nIt's worth noting that the exact shade of blue can vary depending on a number of factors, including the time of day, the amount of dust and water vapor in the atmosphere, and the angle of the sunlight. For example, during sunrise
# ...

# %%
ollama.list()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/site-packages/httpcore/_backends/sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/socket.py:844, in create_connection(address, timeout, source_address)
#     843 try:
# --> 844     raise err
#     845 finally:
# ...

# %%
ollama.pull('phi')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/site-packages/httpcore/_backends/sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/socket.py:844, in create_connection(address, timeout, source_address)
#     843 try:
# --> 844     raise err
#     845 finally:
# ...

# %%
ollama.pull('llama2')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/site-packages/httpcore/_backends/sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/socket.py:844, in create_connection(address, timeout, source_address)
#     843 try:
# --> 844     raise err
#     845 finally:
# ...

# %%
ollama.list()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/site-packages/httpcore/_backends/sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#
# File ~/opt/anaconda3/envs/PyTorch/lib/python3.9/socket.py:844, in create_connection(address, timeout, source_address)
#     843 try:
# --> 844     raise err
#     845 finally:
# ...
